# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("new_insurance_data (1).csv")
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
df.shape
# Out:
# (1338, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
cols = df.columns
cols
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
# Histogram
plt.hist(df['age'])
plt.xlabel('age')
plt.ylabel('No. of People')
plt.show()

# %%
sns.countplot(x = 'age', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = df, x = 'smoker', y = 'age')
plt.show()

# %%
# Statistical component analysis
df.describe()
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1287.000000  1287.000000  1287.000000   1287.000000
# mean     39.419580    30.655746     1.094794  33498.578933
# std      14.051987     6.086323     1.202782  15611.720348
# min      18.000000    15.960000     0.000000   2912.590584
# 25%      27.000000    26.220000     0.000000  20905.974820
# 50%      40.000000    30.360000     1.000000  33968.774160
# 75%      51.000000    34.600000     2.000000  45152.414195
# max      64.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1287.000000  1.287000e+03          1.287000e+03
# mean            15.247086  9.113778e+05          1.579929e+07
# std              7.457366  9.083364e+04          2.653821e+07
# min              1.000000  6.991570e+05          2.945253e+04
# 25%              9.000000  8.489270e+05          4.114357e+06
# ...

# %%
# Deleting outliers and calculating IQR

# %%
cols
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
# Creating a code to get boxplots for all the columns having numeric dtypes.
for i in cols:
    if(df[i].dtypes == 'int64' or df[i].dtypes == 'float64'):
        plt.boxplot(df[i])
        plt.xlabel(i)
        plt.ylabel('Outliers')
        plt.show()

# %%
# Removal of outliers using IQR method

# %%
# For bmi column
Q1 = df.bmi.quantile(0.25)
Q3 = df.bmi.quantile(0.75)

IQR = Q3 - Q1

df = df[(df.bmi >= Q1 - 1.5 * (IQR)) & (df.bmi <= Q3 + 1.5 * (IQR))]

# For past_consultations column
Q1 = df.past_consultations.quantile(0.25)
Q3 = df.past_consultations.quantile(0.75)

IQR = Q3 - Q1

df = df[(df.past_consultations >= Q1 - 1.5 * (IQR)) & (df.past_consultations <= Q3 + 1.5 * (IQR))]

# For Hospital_expenditure column
Q1 = df.Hospital_expenditure.quantile(0.25)
Q3 = df.Hospital_expenditure.quantile(0.75)

IQR = Q3 - Q1

df = df[(df.Hospital_expenditure >= Q1 - 1.5 * (IQR)) & (df.Hospital_expenditure <= Q3 + 1.5 * (IQR))]

# For NUmber_of_past_hospitalizations column
Q1 = df.NUmber_of_past_hospitalizations.quantile(0.25)
Q3 = df.NUmber_of_past_hospitalizations.quantile(0.75)

IQR = Q3 - Q1

df = df[(df.NUmber_of_past_hospitalizations >= Q1 - 1.5 * (IQR)) & (df.NUmber_of_past_hospitalizations <= Q3 + 1.5 * (IQR))]

# For Anual_Salary column
Q1 = df.Anual_Salary.quantile(0.25)
Q3 = df.Anual_Salary.quantile(0.75)

IQR = Q3 - Q1

df = df[(df.Anual_Salary >= Q1 - 1.5 * (IQR)) & (df.Anual_Salary <= Q3 + 1.5 * (IQR))]

# For charges column
Q1 = df.charges.quantile(0.25)
Q3 = df.charges.quantile(0.75)

IQR = Q3 - Q1

df = df[(df.charges >= Q1 - 1.5 * (IQR)) & (df.charges <= Q3 + 1.5 * (IQR))]

# %%
for i in cols:
    if(df[i].dtypes == 'int64' or df[i].dtypes == 'float64'):
        plt.boxplot(df[i])
        plt.xlabel(i)
        plt.ylabel('Outliers')
        plt.show()

# %%
# Correlation
corr = df.corr(numeric_only = True)
corr
# Out:
#                                       age       bmi  children  Claim_Amount  \
# age                              1.000000  0.184940 -0.143992      0.064182
# bmi                              0.184940  1.000000  0.009925     -0.003594
# children                        -0.143992  0.009925  1.000000      0.004841
# Claim_Amount                     0.064182 -0.003594  0.004841      1.000000
# past_consultations               0.134967 -0.018801 -0.001525      0.049488
# num_of_steps                     0.655893  0.043890 -0.004774      0.178441
# Hospital_expenditure             0.116488  0.009269 -0.056827      0.033203
# NUmber_of_past_hospitalizations       NaN       NaN       NaN           NaN
# Anual_Salary                     0.401866 -0.001694 -0.058462      0.145756
# charges                          0.558793  0.009719 -0.042421      0.175262
#
#                                  past_consultations  num_of_steps  \
# ...

# %%
sns.heatmap(df.corr(numeric_only = True))
plt.show()

# %%
cols
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
# Model Building

# %%
# To locate the target column and store it in y as dependent variable.

y = df.iloc[:,-1]

# %%
# To store all the features other than target in x as independent variables.

x = df.loc[:,['children', 'Claim_Amount',
       'past_consultations', 'Hospital_expenditure', 'age']]

# %%
# Splitting the variables i.e. x & y
# The variables x & y are split into 2 different categories making it 4 variables in the end.
# 4 variables:- x_train, x_test, y_train, y_test

# Training data is for actual values
# Testing data is for predicted values.

# %%
from sklearn.model_selection import train_test_split         # Library for splitting
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 50)

# %%
# import the algorithm of linear regression
from sklearn.linear_model import LinearRegression

# %%
# Created a model and stored it in the variable lr
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
# .fit() method is used to provide the training data as input in the machine.
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Using the test variables (x_test, y_test) perform predictions of result i.e. predicted outcomes.

# %%
# Crate a variable and make use of .predict() method with x_test as an input in it.
# This gives us the output values that are predicted outputs that are received from the training data

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([ 7228.56831469,  9174.21956305,  4271.22035723,  9180.49744565,
#        10218.88656407, 13435.27035447,  8280.80581741,  9166.13231993,
#        11009.78590327, 12709.75351183,  4725.99281875, 15046.21883227,
#         5803.53302884, 12189.45129674,  9319.63451264, 12290.29201824,
#        11752.29068862,  7593.07227305, 10671.76712434,  4471.09008376,
#         9099.92202754,  6926.80383586, 10742.11043898,  8241.75670901,
#        10263.59845762,  5586.06715017,  2751.61379276, 10655.25591235,
#         7120.52319077, 11418.76939292,  6124.81324864,  4476.03345821,
#         5632.75868644,  8329.97907142, 12420.55544473,  9533.4526399 ,
#        10485.49389689,  8250.76950457,  7938.38341794,  9657.35743733,
#         5049.73271031,  6501.31930532, 13093.00178319,  6123.46092509,
#         9003.75714148, 11255.37998805, 10094.69199392, 10258.308452  ,
#         8161.70549327,  8590.36156515, 10711.39961442, 11391.34089899,
# ...

# %%
# Compare with y_test for better understanding of accuracy of the model built for the comparison of expected outputs and predicted outputs.
# IN short calculate r2s (r2_score)

# %%
from sklearn.metrics import *

# %%
score = r2_score(y_test, pred)
score
# Out:
# 0.5027408082336219

# %% [markdown]
# # Conclusion
# r2_score = 50.27%
#
# This shows that a model is not a good fit for linear regression algorithm.

# %%
# To be covered later
# Perform feature selection i.e. Vif or Iv , Rfe (will be taught in future.)
# Use the different algorithms available i.e. Decision Tree Regressor or Random Forest Regressor.
